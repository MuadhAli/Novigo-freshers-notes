# %%
# !pip install langchain-openai
# Out:
# Requirement already satisfied: langchain-openai in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (1.1.16)
# Requirement already satisfied: langchain-core<2.0.0,>=1.3.0 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from langchain-openai) (1.3.0)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from langchain-openai) (2.32.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from langchain-core<2.0.0,>=1.3.0->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from langchain-core<2.0.0,>=1.3.0->langchain-openai) (0.7.33)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from langchain-core<2.0.0,>=1.3.0->langchain-openai) (26.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from langchain-core<2.0.0,>=1.3.0->langchain-openai) (2.13.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from langchain-core<2.0.0,>=1.3.0->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from langchain-core<2.0.0,>=1.3.0->langchain-openai) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from langchain-core<2.0.0,>=1.3.0->langchain-openai) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from langchain-core<2.0.0,>=1.3.0->langchain-openai) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.3.0->langchain-openai) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai) (2.33.1)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai) (0.25.0)
# Requirement already satisfied: anyio in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai) (4.13.0)
# Requirement already satisfied: certifi in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai) (1.0.9)
# Requirement already satisfied: idna in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai) (3.13)
# Requirement already satisfied: h11>=0.16 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.14.0)
# Requirement already satisfied: sniffio in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.67.3)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.3.0->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.3.0->langchain-openai) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.3.0->langchain-openai) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai) (1.26.20)
# Requirement already satisfied: colorama in C:\Users\avani.nayak\Downloads\Langgraph\myenv_langgraph\Lib\site-packages (from tqdm>4->openai<3.0.0,>=2.26.0->langchain-openai) (0.4.6)

# %%
from typing import TypedDict
from langgraph.graph import StateGraph
from langgraph.checkpoint.sqlite import SqliteSaver
import sqlite3
import langgraph
from IPython.display import Image, display

from langsmith import traceable
import os
from dotenv import load_dotenv
from langsmith import Client
from langchain_openai import ChatOpenAI

# %%
load_dotenv()

os.environ["LANGCHAIN_API_KEY"] = "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"
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = "langgraph-prompt-freshers"
os.environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"

# %%
client = Client()

prompt = client.pull_prompt("sample_prompt:Latest")
client.push_prompt()
print(prompt)
# Out:
# input_variables=['question'] input_types={} partial_variables={} metadata={'lc_hub_owner': '-', 'lc_hub_repo': 'sample_prompt', 'lc_hub_commit_hash': 'd2fe3960b303a44f30f48b7770ffbd00319cc9593240036017970d067afee510'} messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, template='You are a AI Assistant. Answer what user asks! {question}'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, template='{question}'), additional_kwargs={})]

# %%
llm = ChatOpenAI(model="gpt-4o-mini")

chain = prompt | llm

response = chain.invoke({
    "question": "What is LangGraph?"
})

print(response.content)
# Out:
# LangGraph is a framework designed for building applications that leverage large language models (LLMs). It facilitates the integration of various components, such as data sources, models, and workflows, allowing developers to create complex applications more easily. LangGraph provides tools for defining how data flows through different stages of processing, enabling features like natural language understanding, generation, and interaction with APIs. It aims to simplify the development process for applications that require sophisticated language processing capabilities.
