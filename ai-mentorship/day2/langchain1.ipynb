# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
# !pip install -U langchain langchain-openai
# Out:
# Requirement already satisfied: langchain in d:\Freshers-training\.venv\Lib\site-packages (1.2.15)
# Requirement already satisfied: langchain-openai in d:\Freshers-training\.venv\Lib\site-packages (1.1.15)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in d:\Freshers-training\.venv\Lib\site-packages (from langchain) (1.3.0)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in d:\Freshers-training\.venv\Lib\site-packages (from langchain) (1.1.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\Freshers-training\.venv\Lib\site-packages (from langchain) (2.13.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\Freshers-training\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\Freshers-training\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.33)
# Requirement already satisfied: packaging>=23.2.0 in d:\Freshers-training\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\Freshers-training\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\Freshers-training\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\Freshers-training\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\Freshers-training\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in d:\Freshers-training\.venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in d:\Freshers-training\.venv\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.2)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in d:\Freshers-training\.venv\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.10)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in d:\Freshers-training\.venv\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in d:\Freshers-training\.venv\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in d:\Freshers-training\.venv\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in d:\Freshers-training\.venv\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in d:\Freshers-training\.venv\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\Freshers-training\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\Freshers-training\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.33.1)
# Requirement already satisfied: zstandard>=0.23.0 in d:\Freshers-training\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in d:\Freshers-training\.venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.13.0)
# Requirement already satisfied: certifi in d:\Freshers-training\.venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in d:\Freshers-training\.venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: idna in d:\Freshers-training\.venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\Freshers-training\.venv\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\Freshers-training\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.0 in d:\Freshers-training\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\Freshers-training\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in d:\Freshers-training\.venv\Lib\site-packages (from langchain-openai) (2.32.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in d:\Freshers-training\.venv\Lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\Freshers-training\.venv\Lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in d:\Freshers-training\.venv\Lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.14.0)
# Requirement already satisfied: sniffio in d:\Freshers-training\.venv\Lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in d:\Freshers-training\.venv\Lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.67.3)
# Requirement already satisfied: regex>=2022.1.18 in d:\Freshers-training\.venv\Lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\Freshers-training\.venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\Freshers-training\.venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.6.3)
# Requirement already satisfied: colorama in d:\Freshers-training\.venv\Lib\site-packages (from tqdm>4->openai<3.0.0,>=2.26.0->langchain-openai) (0.4.6)

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-4o-mini")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='The Moon does not have a capital or a government, as it is not inhabited and does not have a permanent population. It is a natural satellite of Earth and has been explored mostly through space missions. While there have been discussions and proposals about potential lunar bases and colonies in the future, as of now, it remains a celestial body without any political structure.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 71, 'prompt_tokens': 14, 'total_tokens': 85, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_9aebe3f11b', 'id': 'chatcmpl-DWyg58WAtEKZbb142h2Mr3AMZnWiQ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019daead-b36c-7ce2-91ef-3c395f464460-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 71, 'total_tokens': 85, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
print(response.content)
# Out:
# The Moon does not have a capital or a government, as it is not inhabited and does not have a permanent population. It is a natural satellite of Earth and has been explored mostly through space missions. While there have been discussions and proposals about potential lunar bases and colonies in the future, as of now, it remains a celestial body without any political structure.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-DWyg58WAtEKZbb142h2Mr3AMZnWiQ',
#  'logprobs': None,
#  'model_name': 'gpt-4o-mini-2024-07-18',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': 'fp_9aebe3f11b',
#  'token_usage': {'completion_tokens': 71,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 0,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 14,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 85}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government, so it has no capital. (In fiction, people sometimes imaginate capitals like “Lunapolis” or “Luna City,” but that’s just storytelling.)

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="gpt-4o-mini")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon does not have a capital or any cities, as it is a celestial body without a permanent human settlement. While there have been various missions to explore the Moon, it remains largely uninhabited. Any future lunar settlements would likely establish their own governance structures, but as of now, there is no capital on the Moon.

# %%
# !pip install -U langchain-google-genai
# Out:
# Requirement already satisfied: langchain-google-genai in d:\Freshers-training\.venv\Lib\site-packages (4.2.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in d:\Freshers-training\.venv\Lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.65.0 in d:\Freshers-training\.venv\Lib\site-packages (from langchain-google-genai) (1.73.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.29 in d:\Freshers-training\.venv\Lib\site-packages (from langchain-google-genai) (1.3.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in d:\Freshers-training\.venv\Lib\site-packages (from langchain-google-genai) (2.13.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in d:\Freshers-training\.venv\Lib\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (4.13.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in d:\Freshers-training\.venv\Lib\site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (2.49.2)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in d:\Freshers-training\.venv\Lib\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in d:\Freshers-training\.venv\Lib\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (2.33.1)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in d:\Freshers-training\.venv\Lib\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in d:\Freshers-training\.venv\Lib\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (16.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in d:\Freshers-training\.venv\Lib\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\Freshers-training\.venv\Lib\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in d:\Freshers-training\.venv\Lib\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in d:\Freshers-training\.venv\Lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (3.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\Freshers-training\.venv\Lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in d:\Freshers-training\.venv\Lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (46.0.7)
# Requirement already satisfied: certifi in d:\Freshers-training\.venv\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in d:\Freshers-training\.venv\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\Freshers-training\.venv\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\Freshers-training\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\Freshers-training\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (0.7.33)
# Requirement already satisfied: packaging>=23.2.0 in d:\Freshers-training\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (26.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\Freshers-training\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\Freshers-training\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in d:\Freshers-training\.venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in d:\Freshers-training\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\Freshers-training\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in d:\Freshers-training\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in d:\Freshers-training\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.29->langchain-google-genai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\Freshers-training\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.0 in d:\Freshers-training\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (2.46.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\Freshers-training\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\Freshers-training\.venv\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\Freshers-training\.venv\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (2.6.3)
# Requirement already satisfied: cffi>=2.0.0 in d:\Freshers-training\.venv\Lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (2.0.0)
# Requirement already satisfied: pycparser in d:\Freshers-training\.venv\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in d:\Freshers-training\.venv\Lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai) (0.6.3)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# That's a fun question! The Moon doesn't have a capital city in the way that Earth countries do. It's a celestial body without any permanent human settlements or governments.
#
# So, the answer is: **The Moon has no capital.**

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="gpt-4o-mini")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='0528ad4a-164e-4f28-ab0f-55c57678c71a'),
#               AIMessage(content='There isn’t one. The Moon has no government or country, so there is no capital city in reality.\n\nIf you want a playful fiction-style name, people sometimes use things like Lunopolis, Luna City, or Selene City for a hypothetical Moon capital. Want me to come up with a few more for a story?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1034, 'prompt_tokens': 13, 'total_tokens': 1047, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 960, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DWyjyeA8fymIdTCCVhzuEVqj0toZj', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019daeb1-6215-7eb3-b61c-264a4b10f2b4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 1034, 'total_tokens': 1047, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 960}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t one. The Moon has no government or country, so there is no capital city in reality.
#
# If you want a playful fiction-style name, people sometimes use things like Lunopolis, Luna City, or Selene City for a hypothetical Moon capital. Want me to come up with a few more for a story?

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='5f9703a2-ab48-4ee9-add0-5a4657121a07'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='d1e64365-db85-49c6-a7c8-d90999a2e420', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='3e134ee0-2969-4076-b7f5-c5db319ff6c0'),
#               AIMessage(content='Luna City is a fictional lunar metropolis (there’s no real capital on the Moon). Here’s a rich, self-contained concept you can use for fiction, games, or worldbuilding. If you want it tweaked to a certain vibe (gritty, utopian, corporate-punk, etc.), tell me and I’ll tailor it.\n\nOverview\n- Location: Near the Moon’s equator, along the rim of a large mare on the near side. Built into a network of lava tubes and shielded by regolith to protect against radiation and micrometeoroids.\n- Government: A Lunar Council representing Earth governments, lunar municipalities, and major corporate colonies. The council runs on a mix of technocratic expertise and citizen juries. A rotating “Presidency” handles ceremonial duties every six months.\n- Economy: A resourceful mixed economy focused on in-situ resource utilization (water ice, solar energy, oxygen, metals), lunar construction and 3D printing, science research, and selective space-tourism. Heavy investment from Earth remains, but Luna City has economic autonomy in day-to-day governance.\n- Time and cycle: A 14-Earth-day day, 14-Earth-day night cycle, with energy storage and heat management optimized for long nights. Artificial lighting and gravity are tuned for comfort and efficiency.\n\nCore districts and features\n- The Glass Rim: The outer ring of habitats with transparent cladding that lets residents watch Earthrise. It houses government offices, media, and museums.\n- The Atlas Dome District: A cluster of domes hosting high-density housing, schools, clinics, and civic centers. 3D-printed apartments, modular rooms, and rotating elevators connect levels.\n- The Sea of Tranquility Research Crescent: A hub for scientific labs, ISRU experiments, and robotics training. Visiting researchers from Earth stay in modular lodges.\n- The Lumina Tower: A vertical magnetically cushioned spine containing command centers, communications hubs, and luxury suites for visiting dignitaries and scientists.\n- The Harvest Quarters: Agricultural and food-innovation zone with vertical farms, algae bioreactors, and food-printing kitchens.\n- The Dusttrack District: Raw materials processing, machine shops, and mining logistics. IoT-controlled surface rovers and tethered transport links weave through this area.\n\nArchitecture and life\n- Housing: A mix of inflatable modules reinforced with regolith and 3D-printed shells. Internal gravity is standard, but some corridors use gentle artificial gravity gradients for exercise and health.\n- Shielding: Shielded by several meters of regolith and local basalt to fend off radiation and micrometeoroids. Water ice in nearby shadowed craters is mined and used for life support and fuel.\n- Energy: Solar farms on the sunlit days, with compact fusion or high-density batteries for night. Energy storage enables long-duration experiments and emergency power.\n- Transportation: A network of transit tubes, tethered glide pods, maglev-like rails, and small lunar rovers. Elevator tubes climb from crater floor to rim habitats.\n- Culture: A melting pot of Earth cultures, Moon-born communities, and visiting researchers. Strong emphasis on sustainability, collaboration, and open science. Public art uses basalt, glass, and bioluminescent organisms in domed parks.\n\nSociety, governance, and daily life\n- Citizens and roles: Scientists, engineers, miners, healthcare workers, educators, artists, and service personnel. AI-assisted governance helps optimize resource distribution and safety.\n- Law and order: Civil liberties backed by a Lunar Charter. Emergency protocols for dust storms (industrial analogs), radiation alerts, and habitat breaches. Privacy balanced with communal safety.\n- Education and research: Schools emphasize STEM, lunar history, and AI ethics. Large-scale experiments in microgravity research, atmospheric processing, and materials science occur in dedicated facilities.\n- Health and fitness: Gravity-friendly gyms, oxygen-maintenance ...

# %% [markdown]
# ## Streaming Output

# %%
from IPython.display import Markdown, display

full_response = ""

# Step 1: Stream normally
for token, metadata in agent.stream(
    {
        "messages": [
            HumanMessage(
                content="Tell me all about Luna City, the capital of the Moon."
            )
        ]
    },
    stream_mode="messages"
):
    if token.content:
        print(token.content, end="", flush=True)   # live streaming
        full_response += token.content            # save tokens
# Out:
# Luna City is a fictional concept—the capital of the Moon in a science fiction setting. If you meant a real-world place, there isn’t one. If you’re building a world or writing a story, here’s a thorough, self-contained guide you can use or adapt.
#
# Core concept
# - Name: Luna City
# - Role: Capital and political heart of a semi-autonomous lunar polity (commonly called the Lunar Commonwealth, Lunar Confederation, or simply the Moon State).
# - Vibe: A frontier-meets-megacity hub that blends high-tech infrastructure with a stubborn, optimistic, transnational lunar culture. It’s where Earth’s legacy meets lunar independence.
#
# Location and setting
# - Primary site: The rim of a large lunar crater near the Moon’s south pole (a classic choice is Shackleton Crater), chosen for access to water ice in the crater’s interior and for engineered sunlight on the rim.
# - Environment: Harsh radiation environment, micrometeoroid flux, and days/nights that cycle with the Moon’s day. The city lives inside pressurized habitats and domed spaces, with ice shafts, sun-facing solar farms, and shielded neighborhoods.
# - Architecture: Shielded domes and ringed districts around the crater rim; modular habitats built from 3D-printed regolith composites; exposed solar arrays in sunlit zones; ice vaults and cryo-storage in the cold interior.
#
# Government and politics
# - Government model: A semi-federal lunar government under a Lunar Council, with an elected Mayor-Commander as the executive head and a bicameral legislature (Lunar Assembly and Lunar Senate) representing districts across the Moon.
# - Relationship to Earth: Historically autonomous, with a formal treaty framework that allows Earth-based organs to oversee trade, defense, and interplanetary diplomacy, but lunar security and internal policy are largely self-determined.
# - Key institutions:
#   - The Polis (seat of government) and Polaris Tower (central administrative complex)
#   - Lunar Academy (university and think tanks)
#   - The Archive (data vaults and history)
#   - Lunar Defense Command (military-police fusion)
#   - ISRU Directorate (in-situ resource utilization and industrial planning)
# - Legal quirks: Water and volatile resource rights are the backbone of the economy; leases and “ice contracts” govern mining, with a strong emphasis on long-term sustainability and climate management inside the habitat rings.
#
# Economy and resources
# - Primary industries:
#   - Water ice mining and processing (fuel, life support, agriculture)
#   - Helium-3 and other lunar volatiles for energy and materials
#   - Microgravity manufacturing and 3D printing (components for Earth and space missions)
#   - Solar energy generation and energy export (to lunar orbit or Earth)
#   - Biotech and life-support technology (self-contained greenhouses, closed-loop ecosystems)
# - Trade: Luna City exports water ice-derived products, precision components, and research services; imports refined goods, advanced electronics, and cultural goods from Earth and other spacefaring colonies.
# - currency and economy: A lunar-dollar hybrid tied to Earth currencies, with a robust system of credits for resource contracts and citizen accounts.
#
# Infrastructure and urban design
# - City structure: A circular, ringed cityscape built around and inside the crater rim. Core districts sit on the rim’s habitable terraces; deeper ice vaults lie in the crater interior, connected by transit tunnels.
# - Transportation:
#   - Surface transit: magnetically levitated pods and all-terrain rovers for short trips.
#   - Vertical access: gravity-adapted elevators and tethered transit lines that connect the rim to the crater floor.
#   - Orbital links: Lunar-orbit platforms and a frequent shuttle service to and from Earth and lunar orbit.
# - Habitats: Pressurized domes and tunnels with life-support loops, radiation shielding, and modular interiors. Greenhouses and hydroponic farms are integrated into the lower rings.
# - Energy: Solar farms on sun-facing rims and high-efficiency reactors or fusion/advanced fission plants to ensure year-round power. Energy storage relies on superconducting grids and hydrogen storage in cold ice vaults.
# - Water and air: Water is extracted from ice, processed into potable water, breathable air, and industrial uses. Atmospheric control is strictly maintained inside habitats; the surface is not breathable.
#
# Society, culture, and daily life
# - Residents: A diverse cadre of Earth-born settlers, lunar-born populations (a few generations of settlers), scientists, engineers, and artists. The culture is cosmopolitan with a strong sense of lunar identity.
# - Language: A blend of Earth languages with lunar-specific slang and terms (e.g., latched from English, Mandarin, Spanish, Hindi, Arabic) and new words tied to lunar life (e.g., ice vaults, sunlids, rimdrift).
# - Festivals and culture:
#   - First Light Festival: Celebrates the first sunrise after a long lunar night and the opening of a new solar farm.
#   - Ice Harvest Night: A winter festival in the interior with ice-sculpture displays reflecting the city’s history.
#   - The Archive Night Market: Cultural performances and historical exhibitions held in the data vaults and domed plazas.
# - Education and science: A strong emphasis on STEM, ISRU, and space ethics. The Lunar Academy runs programs in orbital medicine, cryogenics, atmospheric science for closed-loop habitats, and lunar archaeology (the Moon’s exploration history).
#
# Technology and science
# - Life support: Closed-loop ecological systems, hydroponic farms, recyclable air/water systems, and radiation shielding woven through architecture.
# - ISRU: On-site extraction and processing of ice, regolith alloys, and regolith-based construction materials.
# - Robotics and AI: Autonomous maintenance drones, robotic exosuits for construction and rescue, AI-assisted governance and climate control.
# - Medicine: Space medicine and telemedicine with Earth-based specialists; long-term deep-space health protocols are standard.
#
# History and notable events
# - Founding era: Lunar settlements begin as Earth-funded mining camps; by mid-21st century, a unified lunar governance is formed.
# - Emergence as capital: After decades of autonomous development, Luna City evolves into the political and economic center of the Moon.
# - Notable milestones:
#   - Discovery of stable, accessible water ice in Shackleton-like craters.
#   - First large-scale solar farm completion on the rim.
#   - Establishment of the Archive and a lunar university.
#   - Signing of the Lunar Accord with Earth authorities to formalize governance and trade.
#
# Key districts and landmarks (sample layout)
# - Polis Core: The political heart; Polaris Tower stands here. The City Hall and the Council chambers are in this sector.
# - The Ring: A circular residential and commercial belt with transparent domes offering vistas of the crater’s interior and the starlit sky beyond.
# - Ice Vault Quarter: Deep interiors for ice storage, water processing plants, and cold storage facilities.
# - The Spire Quarter: Research institutions, labs, observatories, and high-tech manufacturers.
# - The Greenhouse Plateau: Agricultural domes and vertical farms; food security hub.
# - The Foundry District: 3D printing facilities, metalworks, and fabrication labs.
# - The Archive Basin: Data vaults, libraries, digital memory banks, and a public data plaza.
# - Helios Row: Large solar arrays, power infrastructure, and energy management facilities.
# - The Port and Dockyards: Lunar transit hubs and cargo facilities linking with lunar orbit and Earth.
#
# Key figures and roles (fictional examples)
# - Mayor-Commander: Elected leader who embodies civil authority and military oversight for lunar internal security.
# - Chief Architect: Oversees habitat design, shielding, and ISRU integration.
# - Director of Ice Operations: Manages ice mining, processing, and water distribution.
# - Head of Lunar Academy: Oversees education, research partnerships, and exchange programs with Earth.
# - Archivist-Librarian: Oversees the Archive and public access to lunar history.
#
# Environmental and safety considerations
# - Radiation: Substantial shielding is built into all habitats; surface stays within radiation-safe protocols.
# - Dust: Lunar regolith is abrasive; inhabitants wear protective suits in unshielded environments and use airlocks.
# - Temperature: The rim has sunlit façades and shaded crevices; climate control is essential to maintain habitable spaces.
# - Meteoroids: Shielded structures and protective armor; reinforced glass and impact-resistant hulls.
#
# Story hooks and plot seeds (if you’re writing)
# - Political intrigue between Earth authorities and the lunar government over water rights and ISRU monopolies.
# - A mystery surrounding an ancient lunar artifact found in the ice vaults that could alter lunar science or politics.
# - A crisis when a solar flare disrupts power across the rim, forcing a rapid relocation of critical facilities.
# - A social conflict between “rim-born” citizens and “ice-dwellers” inside the crater—cultural tensions with a peaceful resolution arc.
# - A new route to independence or a treaty challenge that tests Luna City’s diplomacy with Earth and other lunar settlements.
#
# Visual and design cues
# - A blend of utilitarian practicality and futuristic elegance: glossy solar facades, rugged shielded interiors, and soft lighting from LED ribbons along tunnels.
# - Color palette: whites and pale blues for sterile, glassy surfaces; copper and amber accents in public art; dark, frost-like tones in the interior vaults.
# - Materials: 3D-printed regolith composites, transparent solar skins, and light-diffusing plastics used in public spaces.
#
# If you’re building this for a story, game, or world bible
# - Decide the tempo: Is Luna City a bustling, optimistic hub or a tense, security-focused capital?
# - Pick a scale: Population size (e.g., 200k, 1M, 3M) affects district density, transit, and politics.
# - Choose a pole: Pole near Shackleton-like crater interior or a rim-based hub with spectacular views—each choice informs climate and architecture.
# - Establish a core conflict: Earth oversight vs. lunar autonomy, resource scarcity, or a technological race (e.g., faster propulsion, new ISRU method).
#
# Want me to tailor Luna City to a specific genre or tone? For example:
# - Hard sci-fi version with stricter physics and engineering realism
# - Soft sci-fi/space opera with more romance and grand diplomacy
# - A gritty noir version focusing on crime, espionage, and city politics
# - A family-friendly or children’s adventure version
#
# Tell me your preferred genre, population size, and location (rim vs interior), and I’ll refine Luna City into a cohesive, publishable setting with polished details, dialogue-ready neighborhoods, and a ready-to-use lore bible.

# %%
display(Markdown(full_response))
# Out:
# Luna City is a fictional concept—the capital of the Moon in a science fiction setting. If you meant a real-world place, there isn’t one. If you’re building a world or writing a story, here’s a thorough, self-contained guide you can use or adapt.
#
# Core concept
# - Name: Luna City
# - Role: Capital and political heart of a semi-autonomous lunar polity (commonly called the Lunar Commonwealth, Lunar Confederation, or simply the Moon State).
# - Vibe: A frontier-meets-megacity hub that blends high-tech infrastructure with a stubborn, optimistic, transnational lunar culture. It’s where Earth’s legacy meets lunar independence.
#
# Location and setting
# - Primary site: The rim of a large lunar crater near the Moon’s south pole (a classic choice is Shackleton Crater), chosen for access to water ice in the crater’s interior and for engineered sunlight on the rim.
# - Environment: Harsh radiation environment, micrometeoroid flux, and days/nights that cycle with the Moon’s day. The city lives inside pressurized habitats and domed spaces, with ice shafts, sun-facing solar farms, and shielded neighborhoods.
# - Architecture: Shielded domes and ringed districts around the crater rim; modular habitats built from 3D-printed regolith composites; exposed solar arrays in sunlit zones; ice vaults and cryo-storage in the cold interior.
#
# Government and politics
# - Government model: A semi-federal lunar government under a Lunar Council, with an elected Mayor-Commander as the executive head and a bicameral legislature (Lunar Assembly and Lunar Senate) representing districts across the Moon.
# - Relationship to Earth: Historically autonomous, with a formal treaty framework that allows Earth-based organs to oversee trade, defense, and interplanetary diplomacy, but lunar security and internal policy are largely self-determined.
# - Key institutions:
#   - The Polis (seat of government) and Polaris Tower (central administrative complex)
#   - Lunar Academy (university and think tanks)
#   - The Archive (data vaults and history)
#   - Lunar Defense Command (military-police fusion)
#   - ISRU Directorate (in-situ resource utilization and industrial planning)
# - Legal quirks: Water and volatile resource rights are the backbone of the economy; leases and “ice contracts” govern mining, with a strong emphasis on long-term sustainability and climate management inside the habitat rings.
#
# Economy and resources
# - Primary industries:
#   - Water ice mining and processing (fuel, life support, agriculture)
#   - Helium-3 and other lunar volatiles for energy and materials
#   - Microgravity manufacturing and 3D printing (components for Earth and space missions)
#   - Solar energy generation and energy export (to lunar orbit or Earth)
#   - Biotech and life-support technology (self-contained greenhouses, closed-loop ecosystems)
# - Trade: Luna City exports water ice-derived products, precision components, and research services; imports refined goods, advanced electronics, and cultural goods from Earth and other spacefaring colonies.
# - currency and economy: A lunar-dollar hybrid tied to Earth currencies, with a robust system of credits for resource contracts and citizen accounts.
#
# Infrastructure and urban design
# - City structure: A circular, ringed cityscape built around and inside the crater rim. Core districts sit on the rim’s habitable terraces; deeper ice vaults lie in the crater interior, connected by transit tunnels.
# - Transportation:
#   - Surface transit: magnetically levitated pods and all-terrain rovers for short trips.
#   - Vertical access: gravity-adapted elevators and tethered transit lines that connect the rim to the crater floor.
#   - Orbital links: Lunar-orbit platforms and a frequent shuttle service to and from Earth and lunar orbit.
# - Habitats: Pressurized domes and tunnels with life-support loops, radiation shielding, and modular interiors. Greenhouses and hydroponic farms are integrated into the lower rings.
# - Energy: Solar farms on sun-facing rims and high-efficiency reactors or fusion/advanced fission plants to ensure year-round power. Energy storage relies on superconducting grids and hydrogen storage in cold ice vaults.
# - Water and air: Water is extracted from ice, processed into potable water, breathable air, and industrial uses. Atmospheric control is strictly maintained inside habitats; the surface is not breathable.
#
# Society, culture, and daily life
# - Residents: A diverse cadre of Earth-born settlers, lunar-born populations (a few generations of settlers), scientists, engineers, and artists. The culture is cosmopolitan with a strong sense of lunar identity.
# - Language: A blend of Earth languages with lunar-specific slang and terms (e.g., latched from English, Mandarin, Spanish, Hindi, Arabic) and new words tied to lunar life (e.g., ice vaults, sunlids, rimdrift).
# - Festivals and culture:
#   - First Light Festival: Celebrates the first sunrise after a long lunar night and the opening of a new solar farm.
#   - Ice Harvest Night: A winter festival in the interior with ice-sculpture displays reflecting the city’s history.
#   - The Archive Night Market: Cultural performances and historical exhibitions held in the data vaults and domed plazas.
# - Education and science: A strong emphasis on STEM, ISRU, and space ethics. The Lunar Academy runs programs in orbital medicine, cryogenics, atmospheric science for closed-loop habitats, and lunar archaeology (the Moon’s exploration history).
#
# Technology and science
# - Life support: Closed-loop ecological systems, hydroponic farms, recyclable air/water systems, and radiation shielding woven through architecture.
# - ISRU: On-site extraction and processing of ice, regolith alloys, and regolith-based construction materials.
# - Robotics and AI: Autonomous maintenance drones, robotic exosuits for construction and rescue, AI-assisted governance and climate control.
# - Medicine: Space medicine and telemedicine with Earth-based specialists; long-term deep-space health protocols are standard.
#
# History and notable events
# - Founding era: Lunar settlements begin as Earth-funded mining camps; by mid-21st century, a unified lunar governance is formed.
# - Emergence as capital: After decades of autonomous development, Luna City evolves into the political and economic center of the Moon.
# - Notable milestones:
#   - Discovery of stable, accessible water ice in Shackleton-like craters.
#   - First large-scale solar farm completion on the rim.
#   - Establishment of the Archive and a lunar university.
#   - Signing of the Lunar Accord with Earth authorities to formalize governance and trade.
#
# Key districts and landmarks (sample layout)
# - Polis Core: The political heart; Polaris Tower stands here. The City Hall and the Council chambers are in this sector.
# - The Ring: A circular residential and commercial belt with transparent domes offering vistas of the crater’s interior and the starlit sky beyond.
# - Ice Vault Quarter: Deep interiors for ice storage, water processing plants, and cold storage facilities.
# - The Spire Quarter: Research institutions, labs, observatories, and high-tech manufacturers.
# - The Greenhouse Plateau: Agricultural domes and vertical farms; food security hub.
# - The Foundry District: 3D printing facilities, metalworks, and fabrication labs.
# - The Archive Basin: Data vaults, libraries, digital memory banks, and a public data plaza.
# - Helios Row: Large solar arrays, power infrastructure, and energy management facilities.
# - The Port and Dockyards: Lunar transit hubs and cargo facilities linking with lunar orbit and Earth.
#
# Key figures and roles (fictional examples)
# - Mayor-Commander: Elected leader who embodies civil authority and military oversight for lunar internal security.
# - Chief Architect: Oversees habitat design, shielding, and ISRU integration.
# - Director of Ice Operations: Manages ice mining, processing, and water distribution.
# - Head of Lunar Academy: Oversees education, research partnerships, and exchange programs with Earth.
# - Archivist-Librarian: Oversees the Archive and public access to lunar history.
#
# Environmental and safety considerations
# - Radiation: Substantial shielding is built into all habitats; surface stays within radiation-safe protocols.
# - Dust: Lunar regolith is abrasive; inhabitants wear protective suits in unshielded environments and use airlocks.
# - Temperature: The rim has sunlit façades and shaded crevices; climate control is essential to maintain habitable spaces.
# - Meteoroids: Shielded structures and protective armor; reinforced glass and impact-resistant hulls.
#
# Story hooks and plot seeds (if you’re writing)
# - Political intrigue between Earth authorities and the lunar government over water rights and ISRU monopolies.
# - A mystery surrounding an ancient lunar artifact found in the ice vaults that could alter lunar science or politics.
# - A crisis when a solar flare disrupts power across the rim, forcing a rapid relocation of critical facilities.
# - A social conflict between “rim-born” citizens and “ice-dwellers” inside the crater—cultural tensions with a peaceful resolution arc.
# - A new route to independence or a treaty challenge that tests Luna City’s diplomacy with Earth and other lunar settlements.
#
# Visual and design cues
# - A blend of utilitarian practicality and futuristic elegance: glossy solar facades, rugged shielded interiors, and soft lighting from LED ribbons along tunnels.
# - Color palette: whites and pale blues for sterile, glassy surfaces; copper and amber accents in public art; dark, frost-like tones in the interior vaults.
# - Materials: 3D-printed regolith composites, transparent solar skins, and light-diffusing plastics used in public spaces.
#
# If you’re building this for a story, game, or world bible
# - Decide the tempo: Is Luna City a bustling, optimistic hub or a tense, security-focused capital?
# - Pick a scale: Population size (e.g., 200k, 1M, 3M) affects district density, transit, and politics.
# - Choose a pole: Pole near Shackleton-like crater interior or a rim-based hub with spectacular views—each choice informs climate and architecture.
# - Establish a core conflict: Earth oversight vs. lunar autonomy, resource scarcity, or a technological race (e.g., faster propulsion, new ISRU method).
#
# Want me to tailor Luna City to a specific genre or tone? For example:
# - Hard sci-fi version with stricter physics and engineering realism
# - Soft sci-fi/space opera with more romance and grand diplomacy
# - A gritty noir version focusing on crime, espionage, and city politics
# - A family-friendly or children’s adventure version
#
# Tell me your preferred genre, population size, and location (rim vs interior), and I’ll refine Luna City into a cohesive, publishable setting with polished details, dialogue-ready neighborhoods, and a ready-to-use lore bible.
